# %%
import librosa
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import warnings
warnings.filterwarnings("ignore")

# %%
samples, sample_rate = librosa.load('recording.wav', sr=18000)
plt.figure()
plt.plot(samples)
plt.xlabel('time')
plt.ylabel('Amplitude')
plt.plot()
# Out:
# []
